# %%
amylist = [ 'Payghan' , 'Atul' , 'Sopan']
print(mylist)
# Out:
# ['Payghan', 'Atul', 'Sopan']

# %%
i=2
while i>=0:
  print("*")
  i -=2
# Out:
# *
# *

# %%
for i in range(-1,1):
  print("#")
# Out:
# #
# #

# %%
z=10
y=0
x=z>y or z==y
print(x)
# Out:
# True

# %%
my_list = [3,1,-1]
my_list[-1] = my_list[-2]
print(my_list)
# Out:
# [3, 1, 1]

# %%
vals=[0,1,2]
vals[0],vals[1]=vals[1],vals[2]
print(vals)
# Out:
# [1, 2, 2]

# %%
nums=[]
valss=nums[:]
valss.append(1)
print(nums)
# Out:
# []

# %%
qqq = [0,1,2,3]
x = 1
for elem in qqq:
  x*=elem
print(x)
# Out:
# 0

# %%
a=1//2*3
print(a)
# Out:
# 0

# %%
q= int(input())
w= int(input())
q=q/w
w=w/q
print(w)
# Out:
# 2
# 4
# 8.0

# %%
q= int(input())
w= int(input())
q=q//w
w=w//q
print(w)
# Out:
# 2
# 4
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# <ipython-input-17-e934363de308> in <cell line: 4>()
#       2 w= int(input())
#       3 q=q//w
# ----> 4 w=w//q
#       5 print(w)
#
# ZeroDivisionError: integer division or modulo by zero

# %%
a=input()
b=int(input())
print(a*b)
# Out:
# 3
# 6
# 333333

# %%
p=1/1
print(p)
# Out:
# 1.0

# %%
a=input()
b=input()
print(a+b)
# Out:
# 2
# 4
# 24

# %%
y=2+3*5
print(y)
# Out:
# 17

# %%
x=1
y=2
z=x
x=y
y=z
print(x,y)
# Out:
# 2 1

# %%
z=y=x=1
print(x,y,z, sep="*")
# Out:
# 1*1*1

# %%
x= int(input())
y=int(input())
x=x%y
x=x%y
y=y%x
print(y)
# Out:
# 11
# 4
# 1

# %%
x=1/2+3//3+4**2
print(x)
# Out:
# 17.5
