# %%
roductdetails=[]
supplier=dict()
customer=[]
gender={}
fp1=open("/Sales.csv","r")
data=fp1.readline()
while(True):
 data=fp1.readline()
 if not data:
    break;
 print(data)
 data=data.replace("\n","")
 temp=data.split(",")
 productdetails.append(temp[1])
 supplier.update({temp[0]:temp[2]})
 customer.append(temp[3])
 gender.update({temp[3]:temp[4]})
 
fp1.close()
customer=tuple(customer)
print(type(customer))
print("\nProduct Details\n",productdetails,end="")
print("\nCustomer Details\n",customer,end="")
print("\nSupplier Details\n",supplier,end="")
print("\nGender Details\n",gender,end="")


#SPENDTHRIFT
freq={}
for item in customer:
  if item in freq:
    freq[item]+=1
  else:
     freq[item]=1
print(freq)
marklist=sorted(freq.items(), key=lambda 
x:x[1],reverse=True)
sortdic=dict(marklist)
print("Descending order: ",sortdic)
print("Most Popoular Buyer: ",list(sortdic.keys())[0],"\nCount: ",list(sortdic.values())[0])
#GENDER
from collections import Counter
counter=dict(Counter(customer))
names=list(counter.keys())
print(names)
male=0
female=0
for name in names:
 if gender[name]=="Male":
  male=male+1
 if gender[name]=="Female":
  female=female+1
print("Number of Males: ",male)
print("Number of Females: ",female)
# Out:
# P00001,Lenovo Laptop,Raka Ele.,Kaustubh Mahajan,Male
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-18-b7bb88072a0e> in <cell line: 7>()
#      12  data=data.replace("\n","")
#      13  temp=data.split(",")
# ---> 14  productdetails.append(temp[1])
#      15  supplier.update({temp[0]:temp[2]})
#      16  customer.append(temp[3])
#
# NameError: name 'productdetails' is not defined

# %%
#MOST SOLD PRODUCT
freq={}
for item in productdetails:
 if item in freq:
  freq[item]+=1
 else:
  freq[item]=1
print(freq)
marklist=sorted(freq.items(), key=lambda 
x:x[1],reverse=True)
sortdic=dict(marklist)
print("Descending order: ",sortdic)
print("Most Sold Product: ",list(sortdic.keys())[0],"\nCount: ",list(sortdic.values())[0])
