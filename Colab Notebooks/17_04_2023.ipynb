# %%
f=open("Atul.txt","r")
print(f.read())
# Out:
# Atul Soapn Payghan
# 202201090019
# 8806986795
# atul.payghan@mitaoe.ac.in

# %%
f=open("Atul.txt","a")
f.write("MITAOE Mecahnical")
f.close()
f=open("Atul.txt","r")
print(f.read())
# Out:
# Atul Sopan Payghan
# 202201090019
# 8806986795
# atul.payghan@mitaoe.ac.in
# MITAOE Mecahnical
