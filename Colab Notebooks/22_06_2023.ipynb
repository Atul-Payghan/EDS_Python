# %%
import pandas as pd
data = pd.read_csv('/content/dataset2.csv')

nan_df = data[data.isnull().any(axis=1)]
display(nan_df.head())


data = data.dropna(how='all')
data.head(70)
# Out:
# Empty DataFrame
# Columns: [Manufacturer, Model, Sales_in_thousands, Vehicle_type, Price_in_thousands, Engine_size, Horsepower, Wheelbase, Width, Length, Curb_weight, Fuel_capacity, Fuel_efficiency, Latest_Launch]
# Index: []
#    Manufacturer          Model  Sales_in_thousands Vehicle_type  \
# 0         Acura        Integra                  17    Passenger
# 1         Acura             TL                  39    Passenger
# 2          Audi             A8                   1    Passenger
# 3           BMW           323i                  20    Passenger
# 4         Buick        LeSabre                  83    Passenger
# 5      Cadillac        DeVille                  64    Passenger
# 6     Chevrolet       Cavalier                 146    Passenger
# 7     Chevrolet         Malibu                 135    Passenger
# 8     Chevrolet          Metro                  22    Passenger
# 9     Chevrolet         Impala                 108    Passenger
# ...

# %% [markdown]
# https://drive.google.com/drive/folders/1ODD4zyY44nPvJb1TRBhqKPSOHW6Pi3wo?usp=drive_link

# %% [markdown]
# https://drive.google.com/drive/folders/1S5JNXa6IhfBHmOU8x_t6pdSmIJUGRLoq?usp=sharing

# %% [markdown]
# https://stackoverflow.com/questions/27298178/concatenate-strings-from-several-rows-using-pandas-groupby

# %% [markdown]
# https://jamboard.google.com/d/1cbkX9I1cjCyd7LY25USZwWKlyVBu_tyRJGLiOlV_Onw/edit?usp=meet_whiteboard
