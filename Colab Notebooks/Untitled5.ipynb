# %%
n = int(input()) 
scores = list(map(int, input().split()))

minimum = min(scores)
maximum = max(scores)
average = sum(scores)/n

performance_metric = minimum + maximum + average

print(performance_metric)
# Out:
# 4
# -2 -1 2 1
# 0.0
