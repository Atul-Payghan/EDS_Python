# %%
D = dict(name = 'bob',
         age =25,
         jod = 'dev')
print(D)
# Out:
# {'name': 'bob', 'age': 25, 'jod': 'dev'}

# %%
keys = ['name','age','job']
values = ['Bob',25,'dev']
print(keys)
print(values)
# Out:
# ['name', 'age', 'job']
# ['Bob', 25, 'dev']

# %%
keys = ['name','age','job']
values = ['Bob',25,'dev']

D = dict(zip(keys, values))
print(D)
# Out:
# {'name': 'Bob', 'age': 25, 'job': 'dev'}

# %%
keys = ['a','b','c']
defultvalue = 0
