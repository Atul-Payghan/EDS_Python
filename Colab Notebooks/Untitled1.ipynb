# %%
list1=[987,65432,654,657,1,2,3,4,987654321,65428,68432,893218,3554,328465,684321,654,321]
list1.sort()
print(list1)
# Out:
# [1, 2, 3, 4, 321, 654, 654, 657, 987, 3554, 65428, 65432, 68432, 328465, 684321, 893218, 987654321]

# %%
list1=[987,65432,654,657,1,2,3,4,987654321,65428,68432,893218,3554,328465,684321,654,321]
list1.sort(reverse=True)
print(list1)
# Out:
# [987654321, 893218, 684321, 328465, 68432, 65432, 65428, 3554, 987, 657, 654, 654, 321, 4, 3, 2, 1]
