# %%
import csv

f1=open("/content/cg.csv","r")
f2=open("/content/stinfo.csv","r")
f3=open("stud_info","w")

d1=list(csv.reader(f1,delimiter=","))
d2=list(csv.reader(f2,delimiter=","))

print("\nFile 1 contents: ",d1)
print("\nFile 2 contents: ",d2)
d3=[]
for i in range (len(d1)):
  d3.append(d1[i]+d2[i])

print(d3)
cw=csv.writer(f3)
cw.writerows(d3)

print(max(d3))

f1.close()
f2.close()
f3.close()
cgpa=[]
with open('/content/stud_info', mode ='r')as file:
   
  csvFile = csv.reader(file)
 
  for lines in csvFile:
    cgpa.append(float(lines[4]))
    

print("\nMaximum cgpa:", max(cgpa))
print("Minimum cgpa:", min(cgpa))
print("Sum of cgpa:",sum(cgpa))
print("Average cgpa:",sum(cgpa)/len(cgpa))
# Out:
# File 1 contents:  [['Atul', '9.9'], ['Parth', '9.4'], ['Pranva', '8.5'], ['Siddhant', '8.1'], ['Mayank', '10']]
#
# File 2 contents:  [['1', 'Atul', '345'], ['2', 'Parth', '354'], ['3', 'Pranav', '348'], ['4', 'Siddhant', '338'], ['5', 'Mayank', '337']]
# [['Atul', '9.9', '1', 'Atul', '345'], ['Parth', '9.4', '2', 'Parth', '354'], ['Pranva', '8.5', '3', 'Pranav', '348'], ['Siddhant', '8.1', '4', 'Siddhant', '338'], ['Mayank', '10', '5', 'Mayank', '337']]
# ['Siddhant', '8.1', '4', 'Siddhant', '338']
#
# Maximum cgpa: 354.0
# Minimum cgpa: 337.0
# Sum of cgpa: 1722.0
# Average cgpa: 344.4
